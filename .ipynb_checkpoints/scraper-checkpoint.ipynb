# %%
import requests
import pandas as pd
import json
import numpy as np

# %%
URL="https://www.dlsu.edu.ph"

# %%
page = requests.get(URL)

# %% [markdown]
# # Extract all sub-urls from dlsu.edu.ph

# %%
import requests
import html5lib
from bs4 import BeautifulSoup
import re
import time

soup = BeautifulSoup(page.content, 'lxml')
data = []
links = []

url_limit = 50

start = time.time()

def remove_duplicates(l): # remove duplicates and unURL string
    for item in l:
        match = re.search("(?P<url>https?://[^\s]+)", item)
        if match is not None:
            links.append((match.group("url")))


for link in soup.find_all('a', href=True):
    data.append(str(link.get('href')))
    
flag = True
remove_duplicates(data)

while flag:
    try:
        for link in links:
            for j in soup.find_all('a', href=True):
                temp = []
                source_code = requests.get(link)
                soup = BeautifulSoup(source_code.content, 'lxml')
                temp.append(str(j.get('href')))
                remove_duplicates(temp)

                if len(links) > url_limit: # set limitation to number of URLs
                    break
            if len(links) > url_limit:
                break
        if len(links) > url_limit:
            break
    except Exception as e:
        print(e)
        if len(links) > url_limit:
            break
            
for url in links:
    print(url)
    
print ("Elapsed Time: %s" % (time.time() - start))
# Out:
# https://www.dlsu.edu.ph/about-dlsu/
# https://www.dlsu.edu.ph/about-dlsu/ourcorevalues/
# https://www.dlsu.edu.ph/offices/qao/accreditation/
# https://www.dlsu.edu.ph/offices/office-of-the-chancellor/
# https://www.dlsu.edu.ph/university-fellows/
# https://www.dlsu.edu.ph/emeriti/
# https://www.dlsu.edu.ph/brothers/
# https://www.dlsu.edu.ph/lasallianmission/
# https://www.dlsu.edu.ph/offices/
# https://www.dlsu.edu.ph/inside/board-advisors/
# https://www.dlsu.edu.ph/admissions/scholarships/
# https://www.dlsu.edu.ph/admissions/graduate/
# https://www.dlsu.edu.ph/integrated-school/
# https://www.dlsu.edu.ph/integrated-school/
# https://www.dlsu.edu.ph/integrated-school/
# https://www.dlsu.edu.ph/integratedschool-test/senior-high-school/
# https://www.dlsu.edu.ph/colleges/
# https://www.dlsu.edu.ph/colleges/gcoe/overview/
# http://www.dlsu.edu.ph/wp-content/uploads/pdf/laguna-campus/dlsu-laguna-campus-viewbook.pdf
# https://www.dlsu.edu.ph/admissions/graduate/graduate-viewbooks/
# https://www.dlsu.edu.ph/wp-content/uploads/pdf/viewbook/graduate/bag-ced-graduate-viewbook.pdf
# https://www.dlsu.edu.ph/wp-content/uploads/pdf/viewbook/graduate/ccs-graduate-viewbook.pdf
# https://www.dlsu.edu.ph/wp-content/uploads/pdf/viewbook/graduate/cla-graduate-viewbook.pdf
# https://www.dlsu.edu.ph/wp-content/uploads/pdf/viewbook/graduate/cos-graduate-viewbook.pdf
# https://www.dlsu.edu.ph/wp-content/uploads/pdf/viewbook/graduate/gcoe-graduate-viewbook.pdf
# https://www.dlsu.edu.ph/wp-content/uploads/pdf/viewbook/graduate/rvr-cob-graduate-viewbook.pdf
# https://www.dlsu.edu.ph/shs-research-congress/%20
# https://www.dlsu.edu.ph/soll/
# http://enroll.dlsu.edu.ph/dlsu/dts
# https://www.dlsu.edu.ph/offices/registrar/document_request/
# https://www.dlsu.edu.ph/offices/hub/cav-ched-requests/
# https://www.dlsu.edu.ph/research/
# https://www.dlsu.edu.ph/conferences/
# https://www.dlsu.edu.ph/research/research-centers/
# https://www.dlsu.edu.ph/research/research-centers/shore/
# https://www.dlsu.edu.ph/research/research-centers/aki/programs-activities-aki/young-economists-convention-aki/
# https://www.dlsu.edu.ph/research/research-centers/bnscwc/
# https://www.dlsu.edu.ph/research/research-centers/southeast-asia-research-center-and-hub/
# https://www.dlsu.edu.ph/research/research-centers/yuchengco-center/
# https://www.dlsu.edu.ph/research/research-centers/cesdr/
# https://www.dlsu.edu.ph/research/research-centers/censer/
# https://www.dlsu.edu.ph/research/research-centers/ibeht/
# https://www.dlsu-jrig.org/
# https://www.dlsu.edu.ph/research/research-centers/sdrc/
# https://www.dlsu.edu.ph/research/research-centers/tala/
# https://www.dlsu.edu.ph/research/offices/urco/
# https://www.dlsu.edu.ph/wp-content/uploads/pdf/viewbook/graduate/bag-ced-graduate-viewbook.pdf
# https://www.dlsu.edu.ph/wp-content/uploads/pdf/viewbook/graduate/ccs-graduate-viewbook.pdf
# https://www.dlsu.edu.ph/wp-content/uploads/pdf/viewbook/graduate/cla-graduate-viewbook.pdf
# https://www.dlsu.edu.ph/wp-content/uploads/pdf/viewbook/graduate/cos-graduate-viewbook.pdf
# https://www.dlsu.edu.ph/wp-content/uploads/pdf/viewbook/graduate/gcoe-graduate-viewbook.pdf
# https://www.dlsu.edu.ph/online-request-for-documents/
# https://www.dlsu.edu.ph/online-request-for-documents/
# https://www.dlsu.edu.ph/ban-of-single-use-plastics-sups-on-campus/
# https://www.dlsu.edu.ph/ban-of-single-use-plastics-sups-on-campus/
# https://www.dlsu.edu.ph/joint-statement-on-the-news-report-of-the-national-task-force-to-end-local-communist-armed-conflict/
# https://www.dlsu.edu.ph/joint-statement-on-the-news-report-of-the-national-task-force-to-end-local-communist-armed-conflict/
# https://www.dlsu.edu.ph/dlsu-researchers-shine-in-2020-nast-awards/
# https://www.dlsu.edu.ph/dlsu-researchers-shine-in-2020-nast-awards/
# https://www.dlsu.edu.ph/the-asia-university-rankings/
# https://www.dlsu.edu.ph/the-asia-university-rankings/
# https://www.dlsu.edu.ph/financial-psychological-connectivity-support-during-covid-19/
# https://www.dlsu.edu.ph/financial-psychological-connectivity-support-during-covid-19/
# https://www.dlsu.edu.ph/one-in-mission-lasallians-mount-covid-19-relief-efforts-for-dlsu-community/
# https://www.dlsu.edu.ph/one-in-mission-lasallians-mount-covid-19-relief-efforts-for-dlsu-community/
# https://www.dlsu.edu.ph/la-salles-future-lawyers-lead-volunteer-efforts/
# https://www.dlsu.edu.ph/la-salles-future-lawyers-lead-volunteer-efforts/
# https://www.dlsu.edu.ph/hei-shift-learning-delivery-support-in-line-with-ched-ecq-guidelines/
# https://www.dlsu.edu.ph/hei-shift-learning-delivery-support-in-line-with-ched-ecq-guidelines/
# https://www.facebook.com/DLSU.Manila.100
# https://twitter.com/dlsumanila
# https://www.linkedin.com/school/de-la-salle-university/
# https://www.youtube.com/channel/UC7LXC9usdkDC0YEvWxa_kHQ
# https://twitter.com/DLSUGradStudies
# https://www.facebook.com/DLSU.GradStudies
# https://my.dlsu.edu.ph
# https://animo.sys.dlsu.edu.ph
# https://www.dlsu.edu.ph/safe-space-act-ra11313/
# https://www.dlsu.edu.ph/offices/registrar/cost-of-studies/request-for-documents/
# https://animo.sys.dlsu.edu.ph
# https://my.dlsu.edu.ph
# https://animospace.dlsu.edu.ph
# http://gateway.dlsu.edu.ph
# https://www.dlsu.edu.ph/bituin/hr/
# https://theconcierge.dlsu.edu.ph/
# https://www.dlsu.edu.ph/give/
# https://www.dlsu.edu.ph/offices/registrar/document_request/
# https://www.dlsu.edu.ph/privacy/
# https://www.dlsu.edu.ph/about-dlsu/
# Elapsed Time: 0.4660921096801758

# %% [markdown]
# # Get Name & Email

# %%
def deCFEmail(fp):
    try:
        r = int(fp[:2],16)
        email = ''.join([chr(int(fp[i:i+2], 16) ^ r) for i in range(2, len(fp), 2)])
        return email
    except (ValueError):
        pass

# %%
emailList = []
nameList = []
urlList = []

def emailNameExtractor(urlString):
    getH=requests.get(urlString)
    h=getH.content
    soup=BeautifulSoup(h,'html.parser')
    mailtos = soup.select('a[href]')
    for i in mailtos:
        href=i['href']
        if "email-protect" in href:
            emailList.append(deCFEmail(href.split("#")[1]))
            nameList.append(i.text)
            urlList.append(urlString)

# %%
a = 'https://www.dlsu.edu.ph/colleges/ccs/office-of-the-dean/'
links.append(a)

# %%
emailList = []
nameList = []
urlFrom = []

length = 0
prev_length =  0



for x in range(len(links)):
    prev_length = length
    length = len(emailList)
    
    if prev_length != length: 
        print("Email Length: ",len(emailList), "Name Length: ", len(nameList), "index: ", x)
        
    
    print(links[x])
    
    if links[x].lower().endswith(".pdf"):
        pass
    else:
        try:
            emailNameExtractor(links[x])
        except:
            pass
   
            
emailList
nameList
# Out:
# https://www.dlsu.edu.ph/about-dlsu/
# https://www.dlsu.edu.ph/about-dlsu/ourcorevalues/
# https://www.dlsu.edu.ph/offices/qao/accreditation/
# Email Length:  1 Name Length:  1 index:  3
# https://www.dlsu.edu.ph/offices/office-of-the-chancellor/
# Email Length:  2 Name Length:  2 index:  4
# https://www.dlsu.edu.ph/university-fellows/
# https://www.dlsu.edu.ph/emeriti/
# https://www.dlsu.edu.ph/brothers/
# https://www.dlsu.edu.ph/lasallianmission/
# https://www.dlsu.edu.ph/offices/
# https://www.dlsu.edu.ph/inside/board-advisors/
# https://www.dlsu.edu.ph/admissions/scholarships/
# Email Length:  3 Name Length:  3 index:  11
# https://www.dlsu.edu.ph/admissions/graduate/
# Email Length:  5 Name Length:  5 index:  12
# https://www.dlsu.edu.ph/integrated-school/
# https://www.dlsu.edu.ph/integrated-school/
# https://www.dlsu.edu.ph/integrated-school/
# https://www.dlsu.edu.ph/integratedschool-test/senior-high-school/
# Email Length:  11 Name Length:  11 index:  16
# https://www.dlsu.edu.ph/colleges/
# https://www.dlsu.edu.ph/colleges/gcoe/overview/
# http://www.dlsu.edu.ph/wp-content/uploads/pdf/laguna-campus/dlsu-laguna-campus-viewbook.pdf
# https://www.dlsu.edu.ph/admissions/graduate/graduate-viewbooks/
# https://www.dlsu.edu.ph/wp-content/uploads/pdf/viewbook/graduate/bag-ced-graduate-viewbook.pdf
# https://www.dlsu.edu.ph/wp-content/uploads/pdf/viewbook/graduate/ccs-graduate-viewbook.pdf
# https://www.dlsu.edu.ph/wp-content/uploads/pdf/viewbook/graduate/cla-graduate-viewbook.pdf
# https://www.dlsu.edu.ph/wp-content/uploads/pdf/viewbook/graduate/cos-graduate-viewbook.pdf
# https://www.dlsu.edu.ph/wp-content/uploads/pdf/viewbook/graduate/gcoe-graduate-viewbook.pdf
# https://www.dlsu.edu.ph/wp-content/uploads/pdf/viewbook/graduate/rvr-cob-graduate-viewbook.pdf
# https://www.dlsu.edu.ph/shs-research-congress/%20
# https://www.dlsu.edu.ph/soll/
# Email Length:  12 Name Length:  12 index:  28
# http://enroll.dlsu.edu.ph/dlsu/dts
# https://www.dlsu.edu.ph/offices/registrar/document_request/
# https://www.dlsu.edu.ph/offices/hub/cav-ched-requests/
# Email Length:  13 Name Length:  13 index:  31
# https://www.dlsu.edu.ph/research/
# https://www.dlsu.edu.ph/conferences/
# https://www.dlsu.edu.ph/research/research-centers/
# https://www.dlsu.edu.ph/research/research-centers/shore/
# https://www.dlsu.edu.ph/research/research-centers/aki/programs-activities-aki/young-economists-convention-aki/
# https://www.dlsu.edu.ph/research/research-centers/bnscwc/
# Email Length:  15 Name Length:  15 index:  37
# https://www.dlsu.edu.ph/research/research-centers/southeast-asia-research-center-and-hub/
# Email Length:  16 Name Length:  16 index:  38
# https://www.dlsu.edu.ph/research/research-centers/yuchengco-center/
# https://www.dlsu.edu.ph/research/research-centers/cesdr/
# Email Length:  17 Name Length:  17 index:  40
# https://www.dlsu.edu.ph/research/research-centers/censer/
# https://www.dlsu.edu.ph/research/research-centers/ibeht/
# https://www.dlsu-jrig.org/
# https://www.dlsu.edu.ph/research/research-centers/sdrc/
# Email Length:  18 Name Length:  18 index:  44
# https://www.dlsu.edu.ph/research/research-centers/tala/
# https://www.dlsu.edu.ph/research/offices/urco/
# Email Length:  19 Name Length:  19 index:  46
# https://www.dlsu.edu.ph/wp-content/uploads/pdf/viewbook/graduate/bag-ced-graduate-viewbook.pdf
# https://www.dlsu.edu.ph/wp-content/uploads/pdf/viewbook/graduate/ccs-graduate-viewbook.pdf
# https://www.dlsu.edu.ph/wp-content/uploads/pdf/viewbook/graduate/cla-graduate-viewbook.pdf
# https://www.dlsu.edu.ph/wp-content/uploads/pdf/viewbook/graduate/cos-graduate-viewbook.pdf
# https://www.dlsu.edu.ph/wp-content/uploads/pdf/viewbook/graduate/gcoe-graduate-viewbook.pdf
://www.dlsu.edu.ph/colleges/ccs/office-of-the-dean/
# ['[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  '[email\xa0protected]',
#  'Dr. Rafael A. Cabredo',
#  'Dr. Charibeth K. Cheng',
#  'Ms. Shirley B. Chu',
#  'Dr. Christine Diane L. Ramos',
#  'Dr. Ma. Rowena R. Caguiat',
#  'Mr. Gregory G. Cu',
#  'Dr. Marnel S. Peradilla',
#  'Ms. Arlyn Verina L. Ong-Tiu',
#  'Dr. Ronald M. Pascual',
#  'Ms. Arlyn Verina L. Ong-Tiu',
#  'Mr. Clement Y. Ong',
#  'Dr. Michelle Renee D. Ching',
#  'Ms. Lissa Andrea K. Magpantay',
#  'Mr. Oliver A. Malabanan',
#  'Dr. Michelle Renee D. Ching',
#  'Ms. Lissa Andrea K. Magpantay',
#  'Dr. Briane Paul V. Samson',
#  'Mr. Neil Patrick A. Del Gallego',
#  'Mr. Edward P Tighe',
#  'Dr. Ethel C. Ong',
#  'Mr. Neil Patrick A. Del Gallego',
#  'Ms. Ma. Christine A. Gendrano',
#  'Mr. Ryan Samuel M. Dimaunahan']

# %% [markdown]
# # Combined Email and Name List

# %%
urlList
# Out:
# ['https://www.dlsu.edu.ph/offices/qao/accreditation/',
#  'https://www.dlsu.edu.ph/offices/office-of-the-chancellor/',
#  'https://www.dlsu.edu.ph/admissions/graduate/',
#  'https://www.dlsu.edu.ph/admissions/graduate/',
#  'https://www.dlsu.edu.ph/integratedschool-test/senior-high-school/',
#  'https://www.dlsu.edu.ph/integratedschool-test/senior-high-school/',
#  'https://www.dlsu.edu.ph/integratedschool-test/senior-high-school/',
#  'https://www.dlsu.edu.ph/integratedschool-test/senior-high-school/',
#  'https://www.dlsu.edu.ph/integratedschool-test/senior-high-school/',
#  'https://www.dlsu.edu.ph/integratedschool-test/senior-high-school/',
#  'https://www.dlsu.edu.ph/offices/hub/cav-ched-requests/',
#  'https://www.dlsu.edu.ph/research/research-centers/shore/',
#  'https://www.dlsu.edu.ph/research/research-centers/shore/',
#  'https://www.dlsu.edu.ph/research/research-centers/bnscwc/',
#  'https://www.dlsu.edu.ph/research/research-centers/bnscwc/',
#  'https://www.dlsu.edu.ph/research/research-centers/cesdr/',
#  'https://www.dlsu.edu.ph/research/research-centers/sdrc/',
#  'https://www.dlsu.edu.ph/research/offices/urco/',
#  'https://www.dlsu.edu.ph/offices/qao/accreditation/',
#  'https://www.dlsu.edu.ph/offices/office-of-the-chancellor/',
#  'https://www.dlsu.edu.ph/admissions/scholarships/',
#  'https://www.dlsu.edu.ph/admissions/graduate/',
#  'https://www.dlsu.edu.ph/admissions/graduate/',
#  'https://www.dlsu.edu.ph/integratedschool-test/senior-high-school/',
#  'https://www.dlsu.edu.ph/integratedschool-test/senior-high-school/',
#  'https://www.dlsu.edu.ph/integratedschool-test/senior-high-school/',
#  'https://www.dlsu.edu.ph/integratedschool-test/senior-high-school/',
#  'https://www.dlsu.edu.ph/integratedschool-test/senior-high-school/',
#  'https://www.dlsu.edu.ph/integratedschool-test/senior-high-school/',
#  'https://www.dlsu.edu.ph/soll/',
#  'https://www.dlsu.edu.ph/offices/hub/cav-ched-requests/',
#  'https://www.dlsu.edu.ph/research/research-centers/shore/',
#  'https://www.dlsu.edu.ph/research/research-centers/shore/',
#  'https://www.dlsu.edu.ph/research/research-centers/bnscwc/',
#  'https://www.dlsu.edu.ph/research/research-centers/bnscwc/',
#  'https://www.dlsu.edu.ph/research/research-centers/southeast-asia-research-center-and-hub/',
#  'https://www.dlsu.edu.ph/research/research-centers/cesdr/',
#  'https://www.dlsu.edu.ph/research/research-centers/sdrc/',
#  'https://www.dlsu.edu.ph/research/offices/urco/',
#  'https://www.dlsu.edu.ph/contact-us-new-normal/',
#  'https://www.dlsu.edu.ph/contact-us-new-normal/',
#  'https://www.dlsu.edu.ph/contact-us-new-normal/',
#  'https://www.dlsu.edu.ph/contact-us-new-normal/',
#  'https://www.dlsu.edu.ph/contact-us-new-normal/',
#  'https://www.dlsu.edu.ph/contact-us-new-normal/',
#  'https://www.dlsu.edu.ph/contact-us-new-normal/',
#  'https://www.dlsu.edu.ph/contact-us-new-normal/',
#  'https://www.dlsu.edu.ph/contact-us-new-normal/',
#  'https://www.dlsu.edu.ph/contact-us-new-normal/',
#  'https://www.dlsu.edu.ph/contact-us-new-normal/',
#  'https://www.dlsu.edu.ph/contact-us-new-normal/',
#  'https://www.dlsu.edu.ph/contact-us-new-normal/',
#  'https://www.dlsu.edu.ph/contact-us-new-normal/',
#  'https://www.dlsu.edu.ph/contact-us-new-normal/',
#  'https://www.dlsu.edu.ph/privacy/',
#  'https://www.dlsu.edu.ph/privacy/',
#  'https://www.dlsu.edu.ph/colleges/ccs/office-of-the-dean/',
#  'https://www.dlsu.edu.ph/colleges/ccs/office-of-the-dean/',
#  'https://www.dlsu.edu.ph/colleges/ccs/office-of-the-dean/',
#  'https://www.dlsu.edu.ph/colleges/ccs/office-of-the-dean/',
#  'https://www.dlsu.edu.ph/colleges/ccs/office-of-the-dean/',
#  'https://www.dlsu.edu.ph/colleges/ccs/office-of-the-dean/',
#  'https://www.dlsu.edu.ph/colleges/ccs/office-of-the-dean/',
#  'https://www.dlsu.edu.ph/colleges/ccs/office-of-the-dean/',
#  'https://www.dlsu.edu.ph/colleges/ccs/office-of-the-dean/',
#  'https://www.dlsu.edu.ph/colleges/ccs/office-of-the-dean/',
#  'https://www.dlsu.edu.ph/colleges/ccs/office-of-the-dean/',
#  'https://www.dlsu.edu.ph/colleges/ccs/office-of-the-dean/',
#  'https://www.dlsu.edu.ph/colleges/ccs/office-of-the-dean/',
#  'https://www.dlsu.edu.ph/colleges/ccs/office-of-the-dean/',
#  'https://www.dlsu.edu.ph/colleges/ccs/office-of-the-dean/',
#  'https://www.dlsu.edu.ph/colleges/ccs/office-of-the-dean/',
#  'https://www.dlsu.edu.ph/colleges/ccs/office-of-the-dean/',
#  'https://www.dlsu.edu.ph/colleges/ccs/office-of-the-dean/',
#  'https://www.dlsu.edu.ph/colleges/ccs/office-of-the-dean/',
#  'https://www.dlsu.edu.ph/colleges/ccs/office-of-the-dean/',
#  'https://www.dlsu.edu.ph/colleges/ccs/office-of-the-dean/',
#  'https://www.dlsu.edu.ph/colleges/ccs/office-of-the-dean/',
#  'https://www.dlsu.edu.ph/colleges/ccs/office-of-the-dean/']

# %%
finalList = list(zip(nameList,emailList,urlList))
finalList = set(finalList)
finalList
# Out:
# {('Dr. Briane Paul V. Samson',
#   'briane.samson@dlsu.edu.ph',
#   'https://www.dlsu.edu.ph/colleges/ccs/office-of-the-dean/'),
#  ('Dr. Charibeth K. Cheng',
#   'charibeth.cheng@dlsu.edu.ph',
#   'https://www.dlsu.edu.ph/colleges/ccs/office-of-the-dean/'),
#  ('Dr. Christine Diane L. Ramos',
#   'christine.diane.ramos@dlsu.edu.ph',
#   'https://www.dlsu.edu.ph/colleges/ccs/office-of-the-dean/'),
#  ('Dr. Ethel C. Ong',
#   'ethel.ong@dlsu.edu.ph',
#   'https://www.dlsu.edu.ph/colleges/ccs/office-of-the-dean/'),
#  ('Dr. Ma. Rowena R. Caguiat',
#   'ma.rowena.caguiat@dlsu.edu.ph',
#   'https://www.dlsu.edu.ph/colleges/ccs/office-of-the-dean/'),
#  ('Dr. Marnel S. Peradilla',
#   'marnel.peradilla@dlsu.edu.ph',
#   'https://www.dlsu.edu.ph/colleges/ccs/office-of-the-dean/'),
#  ('Dr. Michelle Renee D. Ching',
#   'michelle.ching@dlsu.edu.ph',
#   'https://www.dlsu.edu.ph/colleges/ccs/office-of-the-dean/'),
#  ('Dr. Rafael A. Cabredo',
#   'rafael.cabredo@dlsu.edu.ph',
#   'https://www.dlsu.edu.ph/colleges/ccs/office-of-the-dean/'),
#  ('Dr. Ronald M. Pascual',
#   'ronald.pascual@dlsu.edu.ph',
#   'https://www.dlsu.edu.ph/colleges/ccs/office-of-the-dean/'),
#  ('Mr. Clement Y. Ong',
#   'clement.ong@dlsu.edu.ph',
#   'https://www.dlsu.edu.ph/colleges/ccs/office-of-the-dean/'),
#  ('Mr. Edward P Tighe',
#   'edward.tighe@dlsu.edu.ph',
#   'https://www.dlsu.edu.ph/colleges/ccs/office-of-the-dean/'),
#  ('Mr. Gregory G. Cu',
#   'gregory.cu@dlsu.edu.ph',
#   'https://www.dlsu.edu.ph/colleges/ccs/office-of-the-dean/'),
#  ('Mr. Neil Patrick A. Del Gallego',
#   'neil.delgallego@dlsu.edu.ph',
#   'https://www.dlsu.edu.ph/colleges/ccs/office-of-the-dean/'),
#  ('Mr. Oliver A. Malabanan',
#   'oliver.malabanan@dlsu.edu.ph',
#   'https://www.dlsu.edu.ph/colleges/ccs/office-of-the-dean/'),
#  ('Mr. Ryan Samuel M. Dimaunahan',
#   'ryan.dimaunahan@dlsu.edu.ph',
#   'https://www.dlsu.edu.ph/colleges/ccs/office-of-the-dean/'),
#  ('Ms. Arlyn Verina L. Ong-Tiu',
#   'arlyn.ong@dlsu.edu.ph',
#   'https://www.dlsu.edu.ph/colleges/ccs/office-of-the-dean/'),
#  ('Ms. Lissa Andrea K. Magpantay',
#   'lissa.magpantay@dlsu.edu.ph',
#   'https://www.dlsu.edu.ph/colleges/ccs/office-of-the-dean/'),
#  ('Ms. Ma. Christine A. Gendrano',
#   'ma.christine.gendrano@dlsu.edu.ph',
#   'https://www.dlsu.edu.ph/colleges/ccs/office-of-the-dean/'),
#  ('Ms. Shirley B. Chu',
#   'shirley.chu@dlsu.edu.ph',
#   'https://www.dlsu.edu.ph/colleges/ccs/office-of-the-dean/'),
#  ('[email\xa0protected]', 'SoLL@dlsu.edu.ph', 'https://www.dlsu.edu.ph/soll/'),
#  ('[email\xa0protected]',
#   'accounting.laguna@dlsu.edu.ph',
#   'https://www.dlsu.edu.ph/contact-us-new-normal/'),
#  ('[email\xa0protected]',
#   'admission.requirements@dlsu.edu.ph',
#   'https://www.dlsu.edu.ph/contact-us-new-normal/'),
#  ('[email\xa0protected]',
#   'bnscwc@dlsu.edu.ph',
#   'https://www.dlsu.edu.ph/research/research-centers/bnscwc/'),
#  ('[email\xa0protected]',
#   'caredesk@dlsu.edu.ph',
#   'https://www.dlsu.edu.ph/contact-us-new-normal/'),
#  ('[email\xa0protected]',
#   'cashiers@dlsu.edu.ph',
#   'https://www.dlsu.edu.ph/contact-us-new-normal/'),
#  ('[email\xa0protected]',
#   'clinic@dlsu.edu.ph',
#   'https://www.dlsu.edu.ph/contact-us-new-normal/'),
#  ('[email\xa0protected]',
#   'concierge@dlsu.edu.ph',
#   'https://www.dlsu.edu.ph/contact-us-new-normal/'),
#  ('[email\xa0protected]',
#   'fernando.santiago@dlsu.edu.ph',
#   'https://www.dlsu.edu.ph/research/research-centers/southeast-asia-research-center-and-hub/'),
#  ('[email\xa0protected]',
#   'graduate.admissions@dlsu.edu.ph',
#   'https://www.dlsu.edu.ph/admissions/graduate/'),
#  ('[email\xa0protected]',
#   'graduate.admissions@dlsu.edu.ph',
#   'https://www.dlsu.edu.ph/contact-us-new-normal/'),
#  ('[email\xa0protected]',
#   'hub@dlsu.edu.ph',
#   'https://www.dlsu.edu.ph/offices/hub/cav-ched-requests/'),
#  ('[email\xa0protected]',
#   'john.iremil.teodoro@dlsu.edu.ph',
#   'https://www.dlsu.edu.ph/research/research-centers/bnscwc/'),
#  ('[email\xa0protected]',
#   'jose.bienvenido.biona@dlsu.edu.ph',
#   'https://www.dlsu.edu.ph/research/research-centers/cesdr/'),
#  ('[email\xa0protected]',
#   'marinestation@dlsu.edu.ph',
#   'https://www.dlsu.edu.ph/research/research-centers/shore/'),
#  ('[email\xa0protected]',
#   'oasis@dlsu.edu.ph',
#   'https://www.dlsu.edu.ph/contact-us-new-normal/'),
#  ('[email\xa0protected]',
#   'oasis@dlsu.edu.ph',
#   'https://www.dlsu.edu.ph/integratedschool-test/senior-high-school/'),
#  ('[email\xa0protected]',
#   'ocfo.studentservices@dlsu.edu.ph',
#   'https://www.dlsu.edu.ph/contact-us-new-normal/'),
#  ('[email\xa0protected]',
#   'opc@dlsu.edu.ph',
#   'https://www.dlsu.edu.ph/offices/office-of-the-chancellor/'),
#  ('[email\xa0protected]',
#   'quality@dlsu.edu.ph',
#   'https://www.dlsu.edu.ph/offices/qao/accreditation/'),
#  ('[email\xa0protected]',
#   'registrar@dlsu.edu.ph',
#   'https://www.dlsu.edu.ph/contact-us-new-normal/'),
#  ('[email\xa0protected]',
#   'satellite.campus@dlsu.edu.ph',
#   'https://www.dlsu.edu.ph/contact-us-new-normal/'),
#  ('[email\xa0protected]',
#   'scholarship@dlsu.edu.ph',
#   'https://www.dlsu.edu.ph/admissions/graduate/'),
#  ('[email\xa0protected]',
#   'scholarships@dlsu.edu.ph',
#   'https://www.dlsu.edu.ph/admissions/scholarships/'),
#  ('[email\xa0protected]',
#   'scholarships@dlsu.edu.ph',
#   'https://www.dlsu.edu.ph/contact-us-new-normal/'),
#  ('[email\xa0protected]',
#   'sdrc@dlsu.edu.ph',
#   'https://www.dlsu.edu.ph/research/research-centers/sdrc/'),
#  ('[email\xa0protected]',
#   'seniorhigh@dlsu.edu.ph',
#   'https://www.dlsu.edu.ph/contact-us-new-normal/'),
#  ('[email\xa0protected]',
#   'seniorhigh@dlsu.edu.ph',
#   'https://www.dlsu.edu.ph/integratedschool-test/senior-high-school/'),
#  ('[email\xa0protected]',
#   'shorecenter@dlsu.edu.ph',
#   'https://www.dlsu.edu.ph/research/research-centers/shore/'),
#  ('[email\xa0protected]',
#   'universityresearchcoordinationoffice@dlsu.edu.ph',
#   'https://www.dlsu.edu.ph/research/offices/urco/')}

# %%
a = 'https://www.dlsu.edu.ph/colleges/ccs/office-of-the-dean/'
testpage = requests.get(a)
soup = BeautifulSoup(testpage.content, 'lxml')

soup
# Out:
# <!DOCTYPE html>
# <html itemscope="" itemtype="http://schema.org/WebPage" lang="en-US">
# <head><link href="https://www.dlsu.edu.ph/wp-content/cache/minify/91abb.default.include.18995b.css" media="all" rel="stylesheet"/>
# <script defer="" src="https://www.dlsu.edu.ph/wp-content/cache/minify/91abb.default.include.51581c.js"></script>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="http://gmpg.org/xfn/11" rel="profile"/>
# <link href="https://www.dlsu.edu.ph/xmlrpc.php" rel="pingback"/>
# <title>Office of the Dean - De La Salle University</title>
# <!-- This site is optimized with the Yoast SEO plugin v11.6 - https://yoast.com/wordpress/plugins/seo/ -->
# <meta content="DLSU provides world-class leaders that shape the College of Computer Studies. View and learn more about them here." name="description"/>
# <link href="https://www.dlsu.edu.ph/colleges/ccs/office-of-the-dean/" rel="canonical"/>
# <meta content="en_US" property="og:locale"/>
# <meta content="article" property="og:type"/>
# <meta content="Office of the Dean - De La Salle University" property="og:title"/>
# <meta content="DLSU provides world-class leaders that shape the College of Computer Studies. View and learn more about them here." property="og:description"/>
# <meta content="https://www.dlsu.edu.ph/colleges/ccs/office-of-the-dean/" property="og:url"/>
# <meta content="De La Salle University" property="og:site_name"/>
# <meta content="https://www.facebook.com/DLSU.Manila.100/" property="article:publisher"/>
# <meta content="CCS" property="article:section"/>
# <meta content="https://www.dlsu.edu.ph/wp-content/uploads/2018/10/dlsu-generic-banner-news.jpg" property="og:image"/>
# <meta content="https://www.dlsu.edu.ph/wp-content/uploads/2018/10/dlsu-generic-banner-news.jpg" property="og:image:secure_url"/>
# <meta content="722" property="og:image:width"/>
# <meta content="410" property="og:image:height"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="DLSU provides world-class leaders that shape the College of Computer Studies. View and learn more about them here." name="twitter:description"/>
# <meta content="Office of the Dean - De La Salle University" name="twitter:title"/>
# <meta content="@DLSUManila" name="twitter:site"/>
# <meta content="https://www.dlsu.edu.ph/wp-content/uploads/2018/10/dlsu-generic-banner-news.jpg" name="twitter:image"/>
# <meta content="@DLSUManila" name="twitter:creator"/>
# <script class="yoast-schema-graph yoast-schema-graph--main" type="application/ld+json">{"@context":"https://schema.org","@graph":[{"@type":"Organization","@id":"https://www.dlsu.edu.ph/#organization","name":"De La Salle University Manila","url":"https://www.dlsu.edu.ph/","sameAs":["https://www.facebook.com/DLSU.Manila.100/","https://www.instagram.com/dlsu/","https://www.youtube.com/channel/UC7LXC9usdkDC0YEvWxa_kHQ","https://twitter.com/DLSUManila"],"logo":{"@type":"ImageObject","@id":"https://www.dlsu.edu.ph/#logo","url":"https://www.dlsu.edu.ph/wp-content/uploads/2017/10/cropped-01.png","width":512,"height":512,"caption":"De La Salle University Manila"},"image":{"@id":"https://www.dlsu.edu.ph/#logo"}},{"@type":"WebSite","@id":"https://www.dlsu.edu.ph/#website","url":"https://www.dlsu.edu.ph/","name":"De La Salle University","publisher":{"@id":"https://www.dlsu.edu.ph/#organization"},"potentialAction":{"@type":"SearchAction","target":"https://www.dlsu.edu.ph/?s={search_term_string}","query-input":"required name=search_term_string"}},{"@type":"ImageObject","@id":"https://www.dlsu.edu.ph/colleges/ccs/office-of-the-dean/#primaryimage","url":"https://www.dlsu.edu.ph/wp-content/uploads/2018/10/dlsu-generic-banner-news.jpg","width":722,"height":410},{"@type":"WebPage","@id":"https://www.dlsu.edu.ph/colleges/ccs/office-of-the-dean/#webpage","url":"https://www.dlsu.edu.ph/colleges/ccs/office-of-the-dean/","inLanguage":"en-US","name":"Office of the Dean - De La Salle University","isPartOf":{"@id":"https://www.dlsu.edu.ph/#website"},"primaryImageOfPage":{"@id":"https://www.dlsu.edu.ph/colleges/ccs/office-of-the-dean/#primaryimage"},"datePublished":"2018-02-14T08:22:42+00:00","dateModified":"2022-10-03T05:33:01+00:00","description":"DLSU provides world-class leaders that shape the College of Computer Studies. View and learn more about them here."}]}</script>
# <!-- / Yoast SEO plugin. -->
# <link href="//assets.juicer.io" rel="dns-prefetch"/>
# <link href="//maxcdn.bootstrapcdn.com" rel="dns-prefetch"/>
# <link href="//s.w.org" rel="dns-prefetch"/>
# <link href="https://www.dlsu.edu.ph/feed/" rel="alternate" title="De La Salle University » Feed" type="application/rss+xml"/>
# <link href="https://www.dlsu.edu.ph/comments/feed/" rel="alternate" title="De La Salle University » Comments Feed" type="application/rss+xml"/>
# <!-- This site uses the Google Analytics by ExactMetrics plugin v6.1.0 - Using Analytics tracking - https://www.exactmetrics.com/ -->
# <script data-cfasync="false" type="text/javascript">
# 	var em_version         = '6.1.0';
# 	var em_track_user      = true;
# 	var em_no_track_reason = '';
#
# 	var disableStr = 'ga-disable-UA-128887324-1';
#
# 	/* Function to detect opted out users */
# 	function __gaTrackerIsOptedOut() {
# 		return document.cookie.indexOf(disableStr + '=true') > -1;
# 	}
#
# 	/* Disable tracking if the opt-out cookie exists. */
# 	if ( __gaTrackerIsOptedOut() ) {
# 		window[disableStr] = true;
# 	}
#
# 	/* Opt-out function */
# 	function __gaTrackerOptout() {
# 	  document.cookie = disableStr + '=true; expires=Thu, 31 Dec 2099 23:59:59 UTC; path=/';
# 	  window[disableStr] = true;
# 	}
#
# 	if ( 'undefined' === typeof gaOptout ) {
# 		function gaOptout() {
# 			__gaTrackerOptout();
# 		}
# 	}
#
# 	if ( em_track_user ) {
# 		(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 			(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 			m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 		})(window,document,'script','//www.google-analytics.com/analytics.js','__gaTracker');
#
# window.ga = __gaTracker;		__gaTracker('create', 'UA-128887324-1', 'auto');
# 		__gaTracker('set', 'forceSSL', true);
# 		__gaTracker('send','pageview', location.pathname + location.search + location.hash);
# 		__gaTracker( function() { window.ga = __gaTracker; } );
# 	} else {
# 		console.log( "" );
# 		(function() {
# 			/* https://developers.google.com/analytics/devguides/collection/analyticsjs/ */
# 			var noopfn = function() {
# 				return null;
# 			};
# 			var noopnullfn = function() {
# 				return null;
# 			};
# 			var Tracker = function() {
# 				return null;
# 			};
# 			var p = Tracker.prototype;
# 			p.get = noopfn;
# 			p.set = noopfn;
# 			p.send = noopfn;
# 			var __gaTracker = function() {
# 				var len = arguments.length;
# 				if ( len === 0 ) {
# 					return;
# 				}
# 				var f = arguments[len-1];
# 				if ( typeof f !== 'object' || f === null || typeof f.hitCallback !== 'function' ) {
# 					console.log( 'Not running function __gaTracker(' + arguments[0] + " ....) because you are not being tracked. " + em_no_track_reason );
# 					return;
# 				}
# 				try {
# 					f.hitCallback();
# 				} catch (ex) {
#
# 				}
# 			};
# 			__gaTracker.create = function() {
# 				return new Tracker();
# 			};
# 			__gaTracker.getByName = noopnullfn;
# 			__gaTracker.getAll = function() {
# 				return [];
# 			};
# 			__gaTracker.remove = noopfn;
# 			window['__gaTracker'] = __gaTracker;
# 			window.ga = __gaTracker;		})();
# 		}
# </script>
# <!-- / Google Analytics by ExactMetrics -->
# <!-- This site uses the Google Analytics by MonsterInsights plugin v7.18.0 - Using Analytics tracking - https://www.monsterinsights.com/ -->
# <!-- Note: MonsterInsights is not currently configured on this site. The site owner needs to authenticate with Google Analytics in the MonsterInsights settings panel. -->
# <!-- No UA code set -->
# <!-- / Google Analytics by MonsterInsights -->
# <link href="https://www.dlsu.edu.ph/wp-content/plugins/wp-google-search/wgs.css" id="wgs-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.dlsu.edu.ph/wp-content/plugins/wp-google-search/wgs2.css" id="wgs2-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.dlsu.edu.ph/wp-content/plugins/wp-google-search/wgs3.css" id="wgs3-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.dlsu.edu.ph/wp-content/plugins/easy-social-icons/css/font-awesome/css/all.min.css" id="cnss_font_awesome_css-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.dlsu.edu.ph/wp-content/plugins/easy-social-icons/css/font-awesome/css/v4-shims.min.css" id="cnss_font_awesome_v4_shims-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="//assets.juicer.io/embed.css" id="juicerstyle-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.dlsu.edu.ph/wp-content/plugins/cookie-notice/css/front.min.css" id="cookie-notice-front-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.dlsu.edu.ph/wp-content/plugins/custom-facebook-feed/css/cff-style.css" id="cff-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://maxcdn.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css" id="sb-font-awesome-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.dlsu.edu.ph/wp-content/plugins/easy-org-chart/css/pseoc.css" id="pseoc_css-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.dlsu.edu.ph/wp-content/plugins/popup-anything-on-click/assets/css/popupaoc-public-style.css" id="popupaoc-public-style-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.dlsu.edu.ph/wp-content/plugins/revslider/public/assets/css/rs6.css" id="rs-plugin-settings-css" media="all" rel="stylesheet" type="text/css"/>
# <style id="rs-plugin-settings-inline-css" type="text/css">
# #rs-demo-id {}
# </style>
# <link href="https://www.dlsu.edu.ph/wp-content/plugins/tabs-responsive/assets/css/font-awesome/css/font-awesome.min.css" id="wpsm_tabs_r-font-awesome-front-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.dlsu.edu.ph/wp-content/plugins/tabs-responsive/assets/css/bootstrap-front.css" id="wpsm_tabs_r_bootstrap-front-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.dlsu.edu.ph/wp-content/plugins/tabs-responsive/assets/css/animate.css" id="wpsm_tabs_r_animate-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.dlsu.edu.ph/wp-content/plugins/3d-flipbook-dflip-lite/assets/css/themify-icons.min.css" id="dflip-icons-style-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.dlsu.edu.ph/wp-content/plugins/3d-flipbook-dflip-lite/assets/css/dflip.min.css" id="dflip-style-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.dlsu.edu.ph/wp-content/plugins/simple-social-icons/css/style.css" id="simple-social-icons-font-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.dlsu.edu.ph/wp-content/tablepress-combined.min.css" id="tablepress-default-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.dlsu.edu.ph/wp-content/plugins/easy-fancybox/css/jquery.fancybox.min.css" id="fancybox-css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="https://www.dlsu.edu.ph/wp-content/plugins/js_composer/assets/css/js_composer.min.css" id="js_composer_front-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="//www.dlsu.edu.ph/wp-content/uploads/js_composer/custom.css" id="js_composer_custom_css-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.dlsu.edu.ph/wp-content/themes/eduma/assets/css/font-awesome.css" id="font-awesome-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.dlsu.edu.ph/wp-content/themes/eduma/assets/css/ionicons.min.css" id="ionicons-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.dlsu.edu.ph/wp-content/themes/eduma/assets/css/font-pe-icon-7.css" id="font-pe-icon-7-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.dlsu.edu.ph/wp-content/themes/eduma/assets/css/flaticon.css" id="flaticon-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.dlsu.edu.ph/wp-content/uploads/tc_stylesheets/eduma.1562553361.css" id="thim-style-options-css" media="all" rel="stylesheet" type="text/css"/>
# <script src="https://www.dlsu.edu.ph/wp-includes/js/jquery/jquery.js" type="text/javascript"></script>
# <script src="https://www.dlsu.edu.ph/wp-includes/js/jquery/ui/core.min.js" type="text/javascript"></script>
# <script src="//assets.juicer.io/embed-no-jquery.js" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var exactmetrics_frontend = {"js_events_tracking":"true","download_extensions":"zip,mp3,mpeg,pdf,docx,pptx,xlsx,rar","inbound_paths":"[{\"path\":\"\\\/go\\\/\",\"label\":\"affiliate\"},{\"path\":\"\\\/recommend\\\/\",\"label\":\"affiliate\"}]","home_url":"https:\/\/www.dlsu.edu.ph","hash_tracking":"true"};
# /* ]]> */
# </script>
# <script src="https://www.dlsu.edu.ph/wp-content/plugins/google-analytics-dashboard-for-wp/assets/js/frontend.min.js" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var cnArgs = {"ajaxUrl":"https:\/\/www.dlsu.edu.ph\/wp-admin\/admin-ajax.php","nonce":"1ee84d7ecd","hideEffect":"fade","position":"bottom","onScroll":"0","onScrollOffset":"100","onClick":"0","cookieName":"cookie_notice_accepted","cookieTime":"2592000","cookieTimeRejected":"2592000","cookiePath":"\/","cookieDomain":"","redirection":"0","cache":"1","refuse":"0","revokeCookies":"0","revokeCookiesOpt":"automatic","secure":"1","coronabarActive":"0"};
# /* ]]> */
# </script>
# <script src="https://www.dlsu.edu.ph/wp-content/plugins/cookie-notice/js/front.min.js" type="text/javascript"></script>
# <script type="text/javascript">
# jQuery(document).ready(function(jQuery){jQuery.datepicker.setDefaults({"closeText":"Close","currentText":"Today","monthNames":["January","February","March","April","May","June","July","August","September","October","November","December"],"monthNamesShort":["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"nextText":"Next","prevText":"Previous","dayNames":["Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday"],"dayNamesShort":["Sun","Mon","Tue","Wed","Thu","Fri","Sat"],"dayNamesMin":["S","M","T","W","T","F","S"],"dateFormat":"yy-mm-dd","firstDay":0,"isRTL":false});});
# </script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var uiAutocompleteL10n = {"noResults":"No results found.","oneResult":"1 result found. Use up and down arrow keys to navigate.","manyResults":"%d results found. Use up and down arrow keys to navigate.","itemSelected":"Item selected."};
# /* ]]> */
# </script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var EM = {"ajaxurl":"https:\/\/www.dlsu.edu.ph\/wp-admin\/admin-ajax.php","locationajaxurl":"https:\/\/www.dlsu.edu.ph\/wp-admin\/admin-ajax.php?action=locations_search","firstDay":"0","locale":"en","dateFormat":"dd\/mm\/yy","ui_css":"https:\/\/www.dlsu.edu.ph\/wp-content\/plugins\/events-manager\/includes\/css\/jquery-ui.min.css","show24hours":"0","is_ssl":"1","txt_search":"Search","txt_searching":"Searching...","txt_loading":"Loading...","event_detach_warning":"Are you sure you want to detach this event? By doing so, this event will be independent of the recurring set of events.","delete_recurrence_warning":"Are you sure you want to delete all recurrences of this event? All events will be moved to trash."};
# /* ]]> */
# </script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var FlowFlowOpts = {"streams":{},"open_in_new":"nope","filter_all":"All","filter_search":"Search","expand_text":"Expand","collapse_text":"Collapse","posted_on":"Posted on","show_more":"Show more","date_style":"wpStyleDate","dates":{"Yesterday":"Yesterday","s":"s","m":"m","h":"h","ago":"ago","months":["Jan","Feb","March","April","May","June","July","Aug","Sept","Oct","Nov","Dec"]},"lightbox_navigate":"Navigate with arrow keys","server_time":"1669862135","forceHTTPS":"nope","isAdmin":"","ajaxurl":"https:\/\/www.dlsu.edu.ph\/wp-admin\/admin-ajax.php","isLog":"","plugin_base":"https:\/\/www.dlsu.edu.ph\/wp-content\/plugins\/flow-flow-social-streams","plugin_ver":"3.1.65"};
# /* ]]> */
# </script>
# <script src="https://www.dlsu.edu.ph/wp-content/plugins/flow-flow-social-streams/js/require-utils.js" type="text/javascript"></script>
# <script src="https://www.dlsu.edu.ph/wp-content/plugins/simple-social-icons/svgxuse.js" type="text/javascript"></script>
# <link href="https://www.dlsu.edu.ph/wp-json/" rel="https://api.w.org/"/>
# <link href="https://www.dlsu.edu.ph/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
# <link href="https://www.dlsu.edu.ph/wp-includes/wlwmanifest.xml" rel="wlwmanifest" type="application/wlwmanifest+xml"/>
# <link href="https://www.dlsu.edu.ph/?p=9964" rel="shortlink"/>
# <link href="https://www.dlsu.edu.ph/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fwww.dlsu.edu.ph%2Fcolleges%2Fccs%2Foffice-of-the-dean%2F" rel="alternate" type="application/json+oembed"/>
# <link href="https://www.dlsu.edu.ph/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fwww.dlsu.edu.ph%2Fcolleges%2Fccs%2Foffice-of-the-dean%2F&amp;format=xml" rel="alternate" type="text/xml+oembed"/>
# <!-- Custom Facebook Feed Custom CSS -->
# <style type="text/css">
# #cff .cff-item{ display: inline-block; width: 23%; height: auto; margin: 0 2.5%; border: none !important; }
# #cff { margin: 10px}
#
#
# </style>
# <script type="application/ld+json">
# 		{
# 		  "@context": "http://schema.org",
# 		  "@type": "Organization",
# 		  "name": "De La Salle University",
# 		  "url": "https://www.dlsu.edu.ph/",
# 		  "sameAs": ["https://www.facebook.com/DLSU.Manila.100","https://twitter.com/dlsumanila","https://www.linkedin.com/school/de-la-salle-university/","https://www.youtube.com/channel/UC7LXC9usdkDC0YEvWxa_kHQ","https://twitter.com/DLSUGradStudies","https://www.facebook.com/DLSU.GradStudies"]
# 		}
# 		</script><style type="text/css">
# 		ul.cnss-social-icon li.cn-fa-icon a:hover{opacity: 0.7!important;color:#81d742!important;}
# 		</style><style type="text/css">.sidenav a,.sidenav-right a{font-family:sans-serif;font-size:16px;color:#fdfdfd;}</style>
# <!-- teachPress -->
# <script src="https://www.dlsu.edu.ph/wp-content/plugins/teachpress/js/frontend.js?ver=7.1.1" type="text/javascript"></script>
# <link href="https://www.dlsu.edu.ph/wp-content/plugins/teachpress/styles/teachpress_front.css?ver=7.1.1" rel="stylesheet" type="text/css"/>
# <!-- END teachPress -->
# <script type="text/javascript">
#                 function tc_insert_internal_css(css) {
#                     var tc_style = document.createElement("style");
#                     tc_style.type = "text/css";
#                     tc_style.setAttribute('data-type', 'tc-internal-css');
#                     var tc_style_content = document.createTextNode(css);
#                     tc_style.appendChild(tc_style_content);
#                     document.head.appendChild(tc_style);
#                 }
#             </script>
# <script data-cfasync="false"> var dFlipLocation = "https://www.dlsu.edu.ph/wp-content/plugins/3d-flipbook-dflip-lite/assets/"; var dFlipWPGlobal = {"text":{"toggleSound":"Turn on\/off Sound","toggleThumbnails":"Toggle Thumbnails","toggleOutline":"Toggle Outline\/Bookmark","previousPage":"Previous Page","nextPage":"Next Page","toggleFullscreen":"Toggle Fullscreen","zoomIn":"Zoom In","zoomOut":"Zoom Out","toggleHelp":"Toggle Help","singlePageMode":"Single Page Mode","doublePageMode":"Double Page Mode","downloadPDFFile":"Download PDF File","gotoFirstPage":"Goto First Page","gotoLastPage":"Goto Last Page","share":"Share","mailSubject":"I wanted you to see this FlipBook","mailBody":"Check out this site {{url}}","loading":"DearFlip: Loading "},"moreControls":"download,pageMode,startPage,endPage,sound","hideControls":"","scrollWheel":"true","backgroundColor":"#777","backgroundImage":"","height":"auto","paddingLeft":"20","paddingRight":"20","controlsPosition":"bottom","duration":800,"soundEnable":"true","enableDownload":"true","enableAnnotation":"false","enableAnalytics":"false","webgl":"true","hard":"none","maxTextureSize":"1600","rangeChunkSize":"524288","zoomRatio":1.5,"stiffness":3,"pageMode":"0","singlePageMode":"0","pageSize":"0","autoPlay":"false","autoPlayDuration":5000,"autoPlayStart":"false","linkTarget":"2","sharePrefix":"dearflip-"};</script> <link href="//fonts.googleapis.com/css?family=Open+Sans" rel="stylesheet" type="text/css"/>
# <meta content="Powered by WPBakery Page Builder - drag and drop page builder for WordPress." name="generator"/>
# <meta content="Powered by Slider Revolution 6.2.22 - responsive, Mobile-Friendly Slider Plugin for WordPress with comfortable drag and drop interface." name="generator"/>
# <style type="text/css">
#                     <!--
#
#             @font-face {
#                 font-family: 'aslsicons2';
#                 src: url('https://www.dlsu.edu.ph/wp-content/plugins/ajax-search-lite/css/fonts/icons2.eot');
#                 src: url('https://www.dlsu.edu.ph/wp-content/plugins/ajax-search-lite/css/fonts/icons2.eot?#iefix') format('embedded-opentype'),
#                      url('https://www.dlsu.edu.ph/wp-content/plugins/ajax-search-lite/css/fonts/icons2.woff2') format('woff2'),
#                      url('https://www.dlsu.edu.ph/wp-content/plugins/ajax-search-lite/css/fonts/icons2.woff') format('woff'),
#                      url('https://www.dlsu.edu.ph/wp-content/plugins/ajax-search-lite/css/fonts/icons2.ttf') format('truetype'),
#                      url('https://www.dlsu.edu.ph/wp-content/plugins/ajax-search-lite/css/fonts/icons2.svg#icons') format('svg');
#                 font-weight: normal;
#                 font-style: normal;
#             }
#             div[id*='ajaxsearchlitesettings'].searchsettings .asl_option_inner label {
#                 font-size: 0px !important;
#                 color: rgba(0, 0, 0, 0);
#             }
#             div[id*='ajaxsearchlitesettings'].searchsettings .asl_option_inner label:after {
#                 font-size: 11px !important;
#                 position: absolute;
#                 top: 0;
#                 left: 0;
#                 z-index: 1;
#             }
#             div[id*='ajaxsearchlite'].wpdreams_asl_container {
#                 width: 160%;
#                 margin: 0px 0px 5px 10%;
#             }
#             div[id*='ajaxsearchliteres'].wpdreams_asl_results div.resdrg span.highlighted {
#                 font-weight: bold;
#                 color: FFFFFF;
#                 background-color: FFFFFF;
#             }
#             div[id*='ajaxsearchliteres'].wpdreams_asl_results .results div.asl_image {
#                 width: 70px;
#                 height: 70px;
#             }
#             div.asl_r .results {
#                 max-height: none;
#             }
#
#                 div.asl_r.asl_w.vertical .results .item::after {
#                     display: block;
#                     position: absolute;
#                     bottom: 0;
#                     content: '';
#                     height: 1px;
#                     width: 100%;
#                     background: #D8D8D8;
#                 }
#                 div.asl_r.asl_w.vertical .results .item.asp_last_item::after {
#                     display: none;
#                 }
#                                     -->
#                 </style>
# <script type="text/javascript">
#                 if ( typeof _ASL !== "undefined" && _ASL !== null && typeof _ASL.initialize !== "undefined" )
#                     _ASL.initialize();
#             </script>
# <link href="https://www.dlsu.edu.ph/wp-content/uploads/2017/10/cropped-logo-32x32.png" rel="icon" sizes="32x32"/>
# <link href="https://www.dlsu.edu.ph/wp-content/uploads/2017/10/cropped-logo-192x192.png" rel="icon" sizes="192x192"/>
# <link href="https://www.dlsu.edu.ph/wp-content/uploads/2017/10/cropped-logo-180x180.png" rel="apple-touch-icon-precomposed"/>
# <meta content="https://www.dlsu.edu.ph/wp-content/uploads/2017/10/cropped-logo-270x270.png" name="msapplication-TileImage"/>
# <script type="text/javascript">function setREVStartSize(e){
# 			//window.requestAnimationFrame(function() {
# 				window.RSIW = window.RSIW===undefined ? window.innerWidth : window.RSIW;
# 				window.RSIH = window.RSIH===undefined ? window.innerHeight : window.RSIH;
# 				try {
# 					var pw = document.getElementById(e.c).parentNode.offsetWidth,
# 						newh;
# 					pw = pw===0 || isNaN(pw) ? window.RSIW : pw;
# 					e.tabw = e.tabw===undefined ? 0 : parseInt(e.tabw);
# 					e.thumbw = e.thumbw===undefined ? 0 : parseInt(e.thumbw);
# 					e.tabh = e.tabh===undefined ? 0 : parseInt(e.tabh);
# 					e.thumbh = e.thumbh===undefined ? 0 : parseInt(e.thumbh);
# 					e.tabhide = e.tabhide===undefined ? 0 : parseInt(e.tabhide);
# 					e.thumbhide = e.thumbhide===undefined ? 0 : parseInt(e.thumbhide);
# 					e.mh = e.mh===undefined || e.mh=="" || e.mh==="auto" ? 0 : parseInt(e.mh,0);
# 					if(e.layout==="fullscreen" || e.l==="fullscreen")
# 						newh = Math.max(e.mh,window.RSIH);
# 					else{
# 						e.gw = Array.isArray(e.gw) ? e.gw : [e.gw];
# 						for (var i in e.rl) if (e.gw[i]===undefined || e.gw[i]===0) e.gw[i] = e.gw[i-1];
# 						e.gh = e.el===undefined || e.el==="" || (Array.isArray(e.el) && e.el.length==0)? e.gh : e.el;
# 						e.gh = Array.isArray(e.gh) ? e.gh : [e.gh];
# 						for (var i in e.rl) if (e.gh[i]===undefined || e.gh[i]===0) e.gh[i] = e.gh[i-1];
#
# 						var nl = new Array(e.rl.length),
# 							ix = 0,
# 							sl;
# 						e.tabw = e.tabhide>=pw ? 0 : e.tabw;
# 						e.thumbw = e.thumbhide>=pw ? 0 : e.thumbw;
# 						e.tabh = e.tabhide>=pw ? 0 : e.tabh;
# 						e.thumbh = e.thumbhide>=pw ? 0 : e.thumbh;
# 						for (var i in e.rl) nl[i] = e.rl[i]<window.RSIW ? 0 : e.rl[i];
# 						sl = nl[0];
# 						for (var i in nl) if (sl>nl[i] && nl[i]>0) { sl = nl[i]; ix=i;}
# 						var m = pw>(e.gw[ix]+e.tabw+e.thumbw) ? 1 : (pw-(e.tabw+e.thumbw)) / (e.gw[ix]);
# 						newh =  (e.gh[ix] * m) + (e.tabh + e.thumbh);
# 					}
# 					if(window.rs_init_css===undefined) window.rs_init_css = document.head.appendChild(document.createElement("style"));
# 					document.getElementById(e.c).height = newh+"px";
# 					window.rs_init_css.innerHTML += "#"+e.c+"_wrapper { height: "+newh+"px }";
# 				} catch(e){
# 					console.log("Failure at Presize of Slider:" + e)
# 				}
# 			//});
# 		  };</script>
# <script type="text/javascript">
#             if (typeof ajaxurl === 'undefined') {
#                 /* <![CDATA[ */
#                 var ajaxurl = "https://www.dlsu.edu.ph/wp-admin/admin-ajax.php";
#                 /* ]]> */
#             }
# 		</script>
# <style data-type="vc_shortcodes-custom-css" type="text/css">.vc_custom_1519294616837{margin-top: 50px !important;}</style><noscript><style> .wpb_animate_when_almost_visible { opacity: 1; }</style></noscript><noscript><style id="rocket-lazyload-nojs-css">.rll-youtube-player, [data-lazy-src]{display:none !important;}</style></noscript></head>
# <body class="page-template-default page page-id-9964 page-child parent-pageid-8755 cookies-not-set group-blog thim-body-preload bg-boxed-image thim-popup-feature eduma-child wpb-js-composer js-comp-ver-6.2.0 vc_responsive" id="thim-body">
# <div id="preload">
# <div class="sk-cube-grid">
# <div class="sk-cube sk-cube1"></div>
# <div class="sk-cube sk-cube2"></div>
# <div class="sk-cube sk-cube3"></div>
# <div class="sk-cube sk-cube4"></div>
# <div class="sk-cube sk-cube5"></div>
# <div class="sk-cube sk-cube6"></div>
# <div class="sk-cube sk-cube7"></div>
# <div class="sk-cube sk-cube8"></div>
# <div class="sk-cube sk-cube9"></div>
# </div> </div>
# <script>
#   function resizeIframe(obj) {
#     obj.style.height = obj.contentWindow.document.body.scrollHeight + 'px';
#   }
# </script>
# <!-- Google Analytics for SysAds -->
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-53963305-2"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-53963305-2');
# </script>
# <!-- Global site tag (gtag.js) - Google Analytics by emmanuel.iluzada@gmail.com -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-727185-1"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-727185-1');
# </script>
# <!-- Global site tag (gtag.js) - Google Analytics by emmanuel.iluzada@dlsu.edu.ph -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-128887324-1"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-128887324-1');
# </script>
# <!-- Mobile Menu-->
# <div class="mobile-menu-wrapper">
# <div class="mobile-menu-inner">
# <div class="icon-wrapper">
# <div class="menu-mobile-effect navbar-toggle close-icon" data-effect="mobile-effect">
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </div>
# </div>
# <nav class="mobile-menu-container mobile-effect">
# <ul class="nav navbar-nav">
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu-item-8366 tc-menu-item tc-menu-depth-0 tc-menu-align-left tc-menu-layout-default" id="menu-item-8366"><a class="tc-menu-inner" data-ps2id-api="true" href="https://www.dlsu.edu.ph/about-dlsu/">About</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-33300 tc-menu-item tc-menu-depth-1" id="menu-item-33300"><a class="tc-menu-inner tc-megamenu-title" data-ps2id-api="true" href="/about-dlsu">About DLSU</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-33250 tc-menu-item tc-menu-depth-2 tc-menu-align-left" id="menu-item-33250"><a class="tc-menu-inner" data-ps2id-api="true" href="/inside/">Facts and Figures</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-33302 tc-menu-item tc-menu-depth-2" id="menu-item-33302"><a class="tc-menu-inner" data-ps2id-api="true" href="/inside/vision-mission">Vision-Mission</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-33303 tc-menu-item tc-menu-depth-2" id="menu-item-33303"><a class="tc-menu-inner" data-ps2id-api="true" href="/guiding-principles">Lasallian Guiding Principles</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-
a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-37084 tc-menu-item tc-menu-depth-3" id="menu-item-37084"><a class="tc-menu-inner" data-ps2id-api="true" href="/colleges/ccs/academic-departments/software-technology/">Software Technology</a></li>
# </ul><!-- End wrapper ul sub -->
# </li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9610 tc-menu-item tc-menu-depth-2 tc-menu-align-left" id="menu-item-9610"><a class="tc-menu-inner" data-ps2id-api="true" href="/colleges/col/">Tañada-Diokno College of Law</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-9609 tc-menu-item tc-menu-depth-2 tc-menu-align-left" id="menu-item-9609"><a class="tc-menu-inner" data-ps2id-api="true" href="/colleges/cla/">College of Liberal Arts</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-37085 tc-menu-item tc-menu-depth-3" id="menu-item-37085"><a class="tc-menu-inner" data-ps2id-api="true" href="/colleges/cla/academic-departments/behavioral-sciences/">Behavioral Sciences</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-37086 tc-menu-item tc-menu-depth-3" id="menu-item-37086"><a class="tc-menu-inner" data-ps2id-api="true" href="/colleges/cla/academic-departments/communication/">Communication</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-37087 tc-menu-item tc-menu-depth-3" id="menu-item-37087"><a class="tc-menu-inner" data-ps2id-api="true" href="/colleges/cla/academic-departments/filipino/">Filipino</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-37088 tc-menu-item tc-menu-depth-3" id="menu-item-37088"><a class="tc-menu-inner" data-ps2id-api="true" href="/colleges/cla/academic-departments/history/">History</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-37089 tc-menu-item tc-menu-depth-3" id="menu-item-37089"><a class="tc-menu-inner" data-ps2id-api="true" href="/colleges/cla/academic-departments/international-studies/">International Studies</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-37094 tc-menu-item tc-menu-depth-3" id="menu-item-37094"><a class="tc-menu-inner" data-ps2id-api="true" href="/colleges/cla/academic-departments/literature/">Literature</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-37090 tc-menu-item tc-menu-depth-3" id="menu-item-37090"><a class="tc-menu-inner" data-ps2id-api="true" href="/colleges/cla/academic-departments/philosophy/">Philosophy</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-37091 tc-menu-item tc-menu-depth-3" id="menu-item-37091"><a class="tc-menu-inner" data-ps2id-api="true" href="/colleges/cla/academic-departments/political-science/">Political Science</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-37092 tc-menu-item tc-menu-depth-3" id="menu-item-37092"><a class="tc-menu-inner" data-ps2id-api="true" href="/colleges/cla/academic-departments/psychology/">Psychology</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-37093 tc-menu-item tc-menu-depth-3" id="menu-item-37093"><a class="tc-menu-inner" data-ps2id-api="true" href="/colleges/cla/academic-departments/theology-religious-education/">Theology and Religious Education</a></li>
# </ul><!-- End wrapper ul sub -->
# </li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-9608 tc-menu-item tc-menu-depth-2 tc-menu-align-left" id="menu-item-9608"><a class="tc-menu-inner" data-ps2id-api="true" href="/colleges/cos/">College of Science</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-37095 tc-menu-item tc-menu-depth-3" id="menu-item-37095"><a class="tc-menu-inner" data-ps2id-api="true" href="/colleges/cos/departments/biology/">Biology</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-37096 tc-menu-item tc-menu-depth-3" id="menu-item-37096"><a class="tc-menu-inner" data-ps2id-api="true" href="/colleges/cos/departments/chemistry/">Chemistry</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-37098 tc-menu-item tc-menu-depth-3" id="menu-item-37098"><a class="tc-menu-inner" data-ps2id-api="true" href="/colleges/cos/departments/mathematics/">Mathematics and Statistics</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-37097 tc-menu-item tc-menu-depth-3" id="menu-item-37097"><a class="tc-menu-inner" data-ps2id-api="true" href="/colleges/cos/departments/physics/">Physics</a></li>
# </ul><!-- End wrapper ul sub -->
# </li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-9607 tc-menu-item tc-menu-depth-2 tc-menu-align-left" id="menu-item-9607"><a class="tc-menu-inner" data-ps2id-api="true" href="https://www.dlsu.edu.ph/colleges/gcoe/overview/">Gokongwei College of Engineering</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-37099 tc-menu-item tc-menu-depth-3" id="menu-item-37099"><a class="tc-menu-inner" data-ps2id-api="true" href="/colleges/gcoe/academic-departments/chemical-engineering/">Chemical Engineering</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-37100 tc-menu-item tc-menu-depth-3" id="menu-item-37100"><a class="tc-menu-inner" data-ps2id-api="true" href="/colleges/gcoe/academic-departments/civil-engineering/">Civil Engineering</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-37101 tc-menu-item tc-menu-depth-3" id="menu-item-37101"><a class="tc-menu-inner" data-ps2id-api="true" href="/colleges/gcoe/academic-departments/electronics-communications-engineering/">Electronics and Communications Engineering</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-37102 tc-menu-item tc-menu-depth-3" id="menu-item-37102"><a class="tc-menu-inner" data-ps2id-api="true" href="/colleges/gcoe/academic-departments/industrial-engineering/">Industrial Engineering</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-37103 tc-menu-item tc-menu-depth-3" id="menu-item-37103"><a class="tc-menu-inner" data-ps2id-api="true" href="/colleges/gcoe/academic-departments/manufacturing-engineering-management/">Manufacturing Engineering and Management</a></li>
# ...
# </a>
# </div><!-- end wrapper-container -->
# <!-- Custom Facebook Feed JS -->
# <script data-cfasync="false" src="/cdn-cgi/scripts/5c5dd728/cloudflare-static/email-decode.min.js"></script><script type="text/javascript">
# var cfflinkhashtags = "true";
# jQuery( document ).ready(function($) {
# $('#cff.feed1').masonry({ itemSelector: '.cff-item' });
#
# if( $(window).width() < 800){
#     $('.feed1').css('display', 'block');
#     $('.feed1').css('float', 'none');
#     $('.feed1').css('width', '100%');
# }
#
# });
# </script>
# <script type="text/javascript">
# var colomatduration = '450';
# var colomatslideEffect = 'slideFade';
# var colomatpauseInit = '';
# var colomattouchstart = '';
# </script>
# <style>
# .colomat-close{
#        float: right;
# position: absolute;
# margin-right: 30%;
# }
#
# .collapseomatic {
# position:aboslute;
# float: right;
# }
#
# </style>
# <div class="toggler sidenav-right-side">
# <span onclick="openNav()">
# <div class="toggler-container">
# <div class="sbar1"></div>
# <div class="sbar2"></div>
# <div class="sbar3"></div>
# </div>
# </span>
# </div>
# <div class="sidenav-right" id="sideSideNav">
# <nav class="sidenav-wrap">
# <a class="sidenav-right closebtn" href="javascript:void(0)" onclick="closeNav()"> × </a>
# <div class="menu-internal-links-container" id="sideNavWrap"><ul><li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-26455 tc-menu-item tc-menu-depth-0 tc-menu-align-left tc-menu-layout-default" id="menu-item-26455"><a class="tc-menu-inner" data-ps2id-api="true" href="https://animo.sys.dlsu.edu.ph">Animo.Sys</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-26454 tc-menu-item tc-menu-depth-0 tc-menu-align-left tc-menu-layout-default" id="menu-item-26454"><a class="tc-menu-inner" data-ps2id-api="true" href="https://my.dlsu.edu.ph">My.LaSalle</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-26929 tc-menu-item tc-menu-depth-0 tc-menu-align-left tc-menu-layout-default" id="menu-item-26929"><a class="tc-menu-inner" data-ps2id-api="true" href="https://animospace.dlsu.edu.ph">AnimoSpace (Canvas)</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-26456 tc-menu-item tc-menu-depth-0 tc-menu-align-left tc-menu-layout-default" id="menu-item-26456"><a class="tc-menu-inner" data-ps2id-api="true" href="http://gateway.dlsu.edu.ph">DLSU Gateway</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-26930 tc-menu-item tc-menu-depth-0 tc-menu-align-left tc-menu-layout-default" id="menu-item-26930"><a class="tc-menu-inner" data-ps2id-api="true" href="https://www.dlsu.edu.ph/bituin/hr/">HRIS Portal</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-26457 tc-menu-item tc-menu-depth-0 tc-menu-align-left tc-menu-layout-default" id="menu-item-26457"><a class="tc-menu-inner" data-ps2id-api="true" href="/southgate">Website Portal</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-85790 tc-menu-item tc-menu-depth-0 tc-menu-layout-default" id="menu-item-85790"><a class="tc-menu-inner" data-ps2id-api="true" href="https://theconcierge.dlsu.edu.ph/">The CONCiERGE</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-71575 tc-menu-item tc-menu-depth-0 tc-menu-layout-default" id="menu-item-71575"><a class="tc-menu-inner" data-ps2id-api="true" href="https://www.dlsu.edu.ph/give/">Give to DLSU</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-75752 tc-menu-item tc-menu-depth-0 tc-menu-layout-default" id="menu-item-75752"><a class="tc-menu-inner" data-ps2id-api="true" href="https://www.dlsu.edu.ph/offices/registrar/document_request/">Online Request for Documents</a></li>
# </ul></div> </nav></div>
# <script data-cfasync="false" type="text/javascript">
#                 window.onload = function() {
#                     var thim_preload = document.getElementById('preload');
#                     if (thim_preload) {
#                         setTimeout(function() {
#                             var body = document.getElementById('thim-body'),
#                                 len = body.childNodes.length,
#                                 class_name = body.className.replace(/(?:^|\s)thim-body-preload(?!\S)/, '').
#                                     replace(/(?:^|\s)thim-body-load-overlay(?!\S)/, '');
#
#                             body.className = class_name;
#                             if (typeof thim_preload !== 'undefined' && thim_preload !== null) {
#                                 for (var i = 0; i < len; i++) {
#                                     if (body.childNodes[i].id !== 'undefined' && body.childNodes[i].id == 'preload') {
#                                         body.removeChild(body.childNodes[i]);
#                                         break;
#                                     }
#                                 }
#                             }
#                         }, 500);
#                     }
#                 };
# 			</script>
# <script>
#             window.addEventListener('load', function() {
#                 /**
#                  * Fix issue there is an empty spacing between image and title of owl-carousel
#                  */
#                 setTimeout(function() {
#                     var $ = jQuery;
#                     var $carousel = $('.thim-owl-carousel-post').each(function() {
#                         $(this).find('.image').css('min-height', 0);
#                         $(window).trigger('resize');
#                     });
#                 }, 500);
#             });
# 		</script>
# <style id="siteorigin-panels-layouts-footer" media="all" type="text/css">/* Layout w6107b5d156707 */ #pgc-w6107b5d156707-0-0 { width:100%;width:calc(100% - ( 0 * 30px ) ) } #pg-w6107b5d156707-0 , #pl-w6107b5d156707 .so-panel:last-child { margin-bottom:0px } #pl-w6107b5d156707 .so-panel { margin-bottom:30px } #pg-w6107b5d156707-0> .panel-row-style { background-image:url(https://www.dlsu.edu.ph/wp-content/uploads/2018/01/ls-panorama-multiply.jpg);background-position:center center;background-size:cover;min-height: 450px } #pg-w6107b5d156707-0.panel-no-style, #pg-w6107b5d156707-0.panel-has-style > .panel-row-style { -webkit-align-items:flex-start;align-items:flex-start } @media (max-width:780px){ #pg-w6107b5d156707-0.panel-no-style, #pg-w6107b5d156707-0.panel-has-style > .panel-row-style { -webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column } #pg-w6107b5d156707-0 > .panel-grid-cell , #pg-w6107b5d156707-0 > .panel-row-style > .panel-grid-cell { width:100%;margin-right:0 } #pl-w6107b5d156707 .panel-grid-cell { padding:0 } #pl-w6107b5d156707 .panel-grid .panel-grid-cell-empty { display:none } #pl-w6107b5d156707 .panel-grid .panel-grid-cell-mobile-last { margin-bottom:0px }  } </style><link href="https://www.dlsu.edu.ph/wp-content/plugins/teachpress/includes/academicons/css/academicons.min.css?ver=4.9.8" id="academicons-css" media="all" rel="stylesheet" type="text/css"/>
# <script type="text/javascript">
# /* <![CDATA[ */
# var scriptParams = {"google_search_engine_id":"016086107893772533417:srhwee5akzk"};
# /* ]]> */
# </script>
# <script src="https://www.dlsu.edu.ph/wp-content/plugins/wp-google-search/assets/js/google_cse_v2.js" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var wpcf7 = {"apiSettings":{"root":"https:\/\/www.dlsu.edu.ph\/wp-json\/contact-form-7\/v1","namespace":"contact-form-7\/v1"},"cached":0};
# /* ]]> */
# </script>
# <script src="https://www.dlsu.edu.ph/wp-content/plugins/custom-facebook-feed/js/cff-scripts.js" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var mPS2id_params = {"instances":{"mPS2id_instance_0":{"selector":"a[href*='#']:not([href='#'])","autoSelectorMenuLinks":"true","excludeSelector":"a[href^='#tab-'], a[href^='#tabs-'], a[data-toggle]:not([data-toggle='tooltip']), a[data-slide], a[data-vc-tabs], a[data-vc-accordion], a.screen-reader-text.skip-link","scrollSpeed":800,"autoScrollSpeed":"true","scrollEasing":"easeInOutQuint","scrollingEasing":"easeOutQuint","forceScrollEasing":"false","pageEndSmoothScroll":"true","stopScrollOnUserAction":"false","autoCorrectScroll":"false","autoCorrectScrollExtend":"false","layout":"vertical","offset":0,"dummyOffset":"false","highlightSelector":"","clickedClass":"mPS2id-clicked","targetClass":"mPS2id-target","highlightClass":"mPS2id-highlight","forceSingleHighlight":"false","keepHighlightUntilNext":"false","highlightByNextTarget":"false","appendHash":"false","scrollToHash":"true","scrollToHashForAll":"true","scrollToHashDelay":0,"scrollToHashUseElementData":"true","scrollToHashRemoveUrlHash":"false","disablePluginBelow":0,"adminDisplayWidgetsId":"true","adminTinyMCEbuttons":"true","unbindUnrelatedClickEvents":"false","unbindUnrelatedClickEventsSelector":"","normalizeAnchorPointTargets":"false","encodeLinks":"false"}},"total_instances":"1","shortcode_class":"_ps2id"};
# /* ]]> */
# </script>
# <script src="https://www.dlsu.edu.ph/wp-content/plugins/page-scroll-to-id/js/page-scroll-to-id.min.js" type="text/javascript"></script>
# <script src="https://www.dlsu.edu.ph/wp-content/plugins/revslider/public/assets/js/rbtools.min.js" type="text/javascript"></script>
# <script src="https://www.dlsu.edu.ph/wp-content/plugins/revslider/public/assets/js/rs6.min.js" type="text/javascript"></script>
# <script src="https://www.dlsu.edu.ph/wp-content/plugins/tabs-responsive/assets/js/bootstrap.js" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var viewsCacheL10n = {"admin_ajax_url":"https:\/\/www.dlsu.edu.ph\/wp-admin\/admin-ajax.php","post_id":"9964"};
# /* ]]> */
# </script>
# <script src="https://www.dlsu.edu.ph/wp-content/plugins/wp-postviews/postviews-cache.js" type="text/javascript"></script>
# <script src="https://www.dlsu.edu.ph/wp-content/plugins/3d-flipbook-dflip-lite/assets/js/dflip.min.js" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var ajaxsearchlite = {"ajaxurl":"https:\/\/www.dlsu.edu.ph\/wp-admin\/admin-ajax.php","backend_ajaxurl":"https:\/\/www.dlsu.edu.ph\/wp-admin\/admin-ajax.php","js_scope":"jQuery"};
# var ASL = {"ajaxurl":"https:\/\/www.dlsu.edu.ph\/wp-admin\/admin-ajax.php","backend_ajaxurl":"https:\/\/www.dlsu.edu.ph\/wp-admin\/admin-ajax.php","js_scope":"jQuery","detect_ajax":"0","scrollbar":"1","js_retain_popstate":"0","version":"4740","fix_duplicates":"1","analytics":{"method":0,"tracking_id":"","string":"?ajax_search={asl_term}","event":{"focus":{"active":1,"action":"focus","category":"ASL","label":"Input focus","value":"1"},"search_start":{"active":0,"action":"search_start","category":"ASL","label":"Phrase: {phrase}","value":"1"},"search_end":{"active":1,"action":"search_end","category":"ASL","label":"{phrase} | {results_count}","value":"1"},"magnifier":{"active":1,"action":"magnifier","category":"ASL","label":"Magnifier clicked","value":"1"},"return":{"active":1,"action":"return","category":"ASL","label":"Return button pressed","value":"1"},"facet_change":{"active":0,"action":"facet_change","category":"ASL","label":"{option_label} | {option_value}","value":"1"},"result_click":{"active":1,"action":"result_click","category":"ASL","label":"{result_title} | {result_url}","value":"1"}}}};
# /* ]]> */
# </script>
# <script src="https://www.dlsu.edu.ph/wp-content/plugins/easy-fancybox/js/jquery.fancybox.min.js" type="text/javascript"></script>
# <script type="text/javascript">
# var fb_timeout, fb_opts={'overlayShow':true,'hideOnOverlayClick':true,'showCloseButton':true,'margin':20,'centerOnScroll':false,'enableEscapeButton':true,'autoScale':true };
# if(typeof easy_fancybox_handler==='undefined'){
# var easy_fancybox_handler=function(){
# jQuery('.nofancybox,a.wp-block-file__button,a.pin-it-button,a[href*="pinterest.com/pin/create"],a[href*="facebook.com/share"],a[href*="twitter.com/share"]').addClass('nolightbox');
# /* IMG */
# var fb_IMG_select='a[href*=".jpg"]:not(.nolightbox,li.nolightbox>a),area[href*=".jpg"]:not(.nolightbox),a[href*=".jpeg"]:not(.nolightbox,li.nolightbox>a),area[href*=".jpeg"]:not(.nolightbox),a[href*=".png"]:not(.nolightbox,li.nolightbox>a),area[href*=".png"]:not(.nolightbox),a[href*=".webp"]:not(.nolightbox,li.nolightbox>a),area[href*=".webp"]:not(.nolightbox)';
# jQuery(fb_IMG_select).addClass('fancybox image');
# var fb_IMG_sections=jQuery('.gallery,.wp-block-gallery,.tiled-gallery,.wp-block-jetpack-tiled-gallery');
# fb_IMG_sections.each(function(){jQuery(this).find(fb_IMG_select).attr('rel','gallery-'+fb_IMG_sections.index(this));});
# jQuery('a.fancybox,area.fancybox,li.fancybox a').each(function(){jQuery(this).fancybox(jQuery.extend({},fb_opts,{'transitionIn':'elastic','easingIn':'easeOutBack','transitionOut':'elastic','easingOut':'easeInBack','opacity':false,'hideOnContentClick':false,'titleShow':true,'titlePosition':'over','titleFromAlt':true,'showNavArrows':true,'enableKeyboardNav':true,'cyclic':false}))});};
# jQuery('a.fancybox-close').on('click',function(e){e.preventDefault();jQuery.fancybox.close()});
# };
# var easy_fancybox_auto=function(){setTimeout(function(){jQuery('#fancybox-auto').trigger('click')},1000);};
# jQuery(easy_fancybox_handler);jQuery(document).on('post-load',easy_fancybox_handler);
# jQuery(easy_fancybox_auto);
# </script>
# <script src="https://www.dlsu.edu.ph/wp-content/plugins/easy-fancybox/js/jquery.easing.min.js" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var thim_js_translate = {"login":"Username","password":"Password","close":"Close"};
# /* ]]> */
# </script>
# <script src="https://www.dlsu.edu.ph/wp-content/themes/eduma/assets/js/thim-scripts.js" type="text/javascript"></script>
# <script src="https://ajax.googleapis.com/ajax/libs/webfont/1.6.26/webfont.js?ver=3.0.22" type="text/javascript"></script>
# <script type="text/javascript">
# WebFont.load({google:{families:['Open Sans:300,300i,400,400i,700,700i', 'Mukta:300,400,500,700']}});
# </script>
# <script src="https://www.dlsu.edu.ph/wp-content/plugins/js_composer/assets/js/dist/js_composer_front.min.js" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var panelsStyles = {"fullContainer":"body"};
# /* ]]> */
# </script>
# <script src="https://www.dlsu.edu.ph/wp-content/plugins/siteorigin-panels/js/styling-2110.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#             /* <![CDATA[ */
#             jQuery(document).ready(function ($) {
#                 $("ul.nav-menu").not(":has(li)").hide().closest('div').hide();
#             });
#             /* ]]> */
#         </script>
# <!-- Cookie Notice plugin v1.3.2 by Digital Factory https://dfactory.eu/ -->
# <div aria-label="Cookie Notice" class="cookie-notice-hidden cookie-revoke-hidden cn-position-bottom" id="cookie-notice" role="banner" style="background-color: rgba(0,112,60,1);"><div class="cookie-notice-container" style="color: #fff;"><span class="cn-text-container" id="cn-notice-text">We use cookies to analyze traffic and improve your experience. This is part of our updated <a href="/Policy" style="color:#AFCB1E">Privacy Policy</a>. </span><span class="cn-buttons-container" id="cn-notice-buttons"><a aria-label="Ok, got it!" class="cn-set-cookie cn-button bootstrap button" data-cookie-set="accept" href="#" id="cn-accept-cookie">Ok, got it!</a><a aria-label="Privacy Policy" class="cn-more-info cn-button bootstrap button" href="https://www.dlsu.edu.ph/privacy/" id="cn-more-info" target="_blank">Privacy Policy</a></span><a aria-label="Ok, got it!" class="cn-close-icon" data-cookie-set="accept" href="javascript:void(0);" id="cn-close-notice"></a></div>
# </div>
# <!-- / Cookie Notice plugin --> <style>
#       body, p
#        {
#           font-size:15px;
#        }
#    </style>
# </body>
# </html>
# <!--
# Performance optimized by W3 Total Cache. Learn more: https://www.boldgrid.com/w3-total-cache/
#
# Page Caching using disk: enhanced
# Minified using disk
#
# Served from: www.dlsu.edu.ph @ 2022-12-01 10:35:35 by W3 Total Cache
# -->

# %%
a = 'https://www.dlsu.edu.ph/colleges/ccs/office-of-the-dean/'
testpage = requests.get(a)
soup2 = BeautifulSoup(testpage.content, 'lxml')

table = soup2.find('div',{'class':'wpb_wrapper'})
table
# Out:
# <div class="wpb_wrapper">
# <div class="wpb_text_column wpb_content_element">
# <div class="wpb_wrapper">
# <table cellpadding="0" cellspacing="0" summary="This table is a chart of the Office of the CCS Dean" width="90%">
# <tbody>
# <tr>
# <td><strong>Dean</strong></td>
# <td><a href="/cdn-cgi/l/email-protection#ea988b8c8b8f86c4898b88988f8e85aa8e86999fc48f8e9fc49a82">Dr. Rafael A. Cabredo</a></td>
# </tr>
# <tr>
# <td><b>Associate Dean</b></td>
# <td><a href="/cdn-cgi/l/email-protection#12717a73607b7077667a3c717a777c7552767e61673c7776673c627a">Dr. Charibeth K. Cheng</a></td>
# </tr>
# <tr class="selected">
# <td><strong>Assistant Dean, External Affairs and Lasallian Mission</strong></td>
# <td><a href="/cdn-cgi/l/email-protection#86f5eeeff4eae3ffa8e5eef3c6e2eaf5f3a8e3e2f3a8f6ee">Ms. Shirley B. Chu</a></td>
# </tr>
# <tr class="selected">
# <td><strong>Assistant Dean, Research and Graduate Studies</strong></td>
# <td><a href="/cdn-cgi/l/email-protection#6f0c071d061c1b06010a410b060e010a411d0e02001c2f0b031c1a410a0b1a411f07">Dr. Christine Diane L. Ramos</a></td>
# </tr>
# <tr class="selected">
# <td><strong>Director, Consulting and Education Center</strong></td>
# <td><a href="/cdn-cgi/l/email-protection#0e636f207c61796b606f206d6f697b676f7a4e6a627d7b206b6a7b207e66">Dr. Ma. Rowena R. Caguiat</a></td>
# </tr>
# <tr class="selected">
# <td><strong>Head, Technical Support Group</strong></td>
# <td><a href="/cdn-cgi/l/email-protection#177065727078656e39746257737b64623972736239677f">Mr. Gregory G. Cu</a></td>
# </tr>
# <tr class="selected">
# <td></td>
# <td></td>
# </tr>
# <tr class="selected">
# <td colspan="2"><strong>Department of Computer Technology </strong></td>
# </tr>
# <tr>
# <td>Chair</td>
#  <td><a href="/cdn-cgi/l/email-protection#f29f93dc919a809b81869b9c97dc95979c9680939c9db2969e8187dc979687dc829a">Ms. Ma. Christine A. Gendrano</a></td>,
#  <td>Program Coordinator (BSIET), Laguna Campus</td>,
#  <td><a href="/cdn-cgi/l/email-protection#cebcb7afa0e0aaa7a3afbba0afa6afa08eaaa2bdbbe0abaabbe0bea6">Mr. Ryan Samuel M. Dimaunahan</a></td>]

# %%
position = []
names = []
emails = []
department = []
urlsList = []

temp = ""
temp_dept = ""

dept = "department"
titles = ["Mr","Dr","Mrs","Ms"]

table_length = len(table.find_all('td'))

for x in range(0,table_length):
    temp = table.find_all('td')[x]
    
    if dept in temp.text:
        temp_dept = temp.text
    elif any(word in temp.text for word in titles):
        names.append(temp.text)
    elif:
        position.append(temp.text)if temp.text == None:
    else:
        department.append(temp_dept)
    
  
    
    
    
    
    #email
#     mailtos = soup.select('a[href]')
#     for i in mailtos:
#         href=i['href']
#         if "email-protect" in href:
#             emails.append(deCFEmail(href.split("#")[1]))
#             #names.append(i.text)
#             urlsList.append(url)
#             #title.append(table.find_all('td')[x-1])

# %%
print(len(names))
print(len(urlsList))
print(len(department))
print(len(position))
# Out:
# 23
# 0
# 55
# 0

# %%
position = list(filter(None, position))

testList = list(zip(names,position))
testList
# Out:
# [('Dr. Rafael A. Cabredo', 'Dean'),
#  ('Dr. Charibeth K. Cheng', 'Associate Dean'),
#  ('Ms. Shirley B. Chu',
#   'Assistant Dean, External Affairs and Lasallian Mission'),
#  ('Dr. Christine Diane L. Ramos',
#   'Assistant Dean, Research and Graduate Studies'),
#  ('Dr. Ma. Rowena R. Caguiat', 'Director, Consulting and Education Center'),
#  ('Mr. Gregory G. Cu', 'Head, Technical Support Group'),
#  ('Dr. Marnel S. Peradilla', 'Department of Computer Technology\xa0'),
#  ('Ms. Arlyn Verina L. Ong-Tiu', 'Chair'),
#  ('Dr. Ronald M. Pascual', 'Vice Chair'),
#  ('Ms. Arlyn Verina L. Ong-Tiu', 'Coordinator, CT Thesis'),
#  ('Mr. Clement Y. Ong', 'Coordinator, Graduate Studies (MINFSEC)'),
#  ('Dr. Michelle Renee D. Ching',
#   'Coordinator, Instructional Computer Technology Laboratory'),
#  ('Ms. Lissa Andrea K. Magpantay', 'Department of Information Technology\xa0'),
#  ('Mr. Oliver A. Malabanan', 'Chair'),
#  ('Dr. Michelle Renee D. Ching', 'Vice Chair'),
#  ('Ms. Lissa Andrea K. Magpantay', 'Coordinator, BSIS and BSIT Capstone'),
#  ('Dr. Briane Paul V. Samson', 'Coordinator, Graduate Studies (DIT)'),
#  ('Mr. Neil Patrick A. Del Gallego',
#   'Coordinator, Graduate Studies (MSIT, MIT)'),
#  ('Mr. Edward P Tighe', 'Department of Software Technology\xa0'),
#  ('Dr. Ethel C. Ong', 'Chair'),
#  ('Mr. Neil Patrick A. Del Gallego', 'Vice Chair'),
#  ('Ms. Ma. Christine A. Gendrano',
#   'Coordinator, BSCS Thesis and BSIET Capstone'),
#  ('Mr. Ryan Samuel M. Dimaunahan',
#   'Coordinator, Graduate Studies (MSCS, PhDCS)')]

# %% [markdown]
# # Convert to txt file

# %%
df = pd.DataFrame (finalList, columns = ['Name', 'Email','url'])
np.savetxt(r'np.txt', df.values, fmt='%s %s %s')

# %% [markdown]
# # Threading

# %% [markdown]
# ## wala pang ginagawa to

# %%
import threading
import time

start = time.time()

def fetch_url(url):
    print ("'%s\' fetched in %ss" % (url, (time.time() - start)))
    
threads = [threading.Thread(target=fetch_url, args=(url,)) for url in links]

for thread in threads:
    thread.start()
    
for thread in threads:
    thread.join()

print ("Elapsed Time: %s" % (time.time() - start))
# Out:
# 'https://www.dlsu.edu.ph/offices/' fetched in 0.0020012855529785156s
# 'https://www.dlsu.edu.ph/soll/' fetched in 0.004004478454589844s
# 'https://www.facebook.com/DLSU.GradStudies' fetched in 0.007005929946899414s'https://www.dlsu.edu.ph/give/' fetched in 0.008007287979125977s
#
# 'https://www.dlsu.edu.ph/research/research-centers/cesdr/' fetched in 0.01101827621459961s
# 'https://www.dlsu.edu.ph/research/research-centers/' fetched in 0.013028621673583984s'https://www.linkedin.com/school/de-la-salle-university/' fetched in 0.015024662017822266s
#
# 'https://www.dlsu.edu.ph/shs-research-congress/%20' fetched in 0.017004728317260742s
# 'https://www.dlsu.edu.ph/colleges/ccs/office-of-the-dean/' fetched in 0.02000141143798828s
# 'https://twitter.com/DLSUGradStudies' fetched in 0.022000789642333984s'https://www.dlsu.edu.ph/wp-content/uploads/2022/06/the-concierge.pdf' fetched in 0.023999929428100586s
#
# 'https://www.dlsu.edu.ph/research/research-centers/bnscwc/' fetched in 0.026002883911132812s
# 'https://www.dlsu.edu.ph/integrated-school/' fetched in 0.02899956703186035s
# 'https://www.dlsu.edu.ph/research/research-centers/tala/' fetched in 0.031004905700683594s
# 'https://my.dlsu.edu.ph' fetched in 0.03300070762634277s
# 'https://www.dlsu.edu.ph/wp-content/uploads/pdf/viewbook/graduate/ccs-graduate-viewbook.pdf' fetched in 0.034998416900634766s
# 'https://www.facebook.com/DLSU.Manila.100' fetched in 0.0370020866394043s
# 'https://twitter.com/dlsumanila' fetched in 0.03800320625305176s
# 'https://www.dlsu.edu.ph/wp-content/uploads/pdf/viewbook/graduate/gcoe-graduate-viewbook.pdf' fetched in 0.04000520706176758s
# 'https://www.dlsu.edu.ph/colleges/gcoe/overview/' fetched in 0.042006731033325195s
# 'https://www.dlsu.edu.ph/research/research-centers/sdrc/' fetched in 0.04400372505187988s
# 'https://www.dlsu.edu.ph/dlsu-return-to-campus-guidelines/' fetched in 0.045998573303222656s
# 'https://www.dlsu.edu.ph/offices/hub/cav-ched-requests/' fetched in 0.0480046272277832s
# 'https://www.dlsu.edu.ph/financial-psychological-connectivity-support-during-covid-19/' fetched in 0.05000615119934082s
# 'https://www.dlsu.edu.ph/offices/registrar/cost-of-studies/request-for-documents/' fetched in 0.052004337310791016s
# 'https://www.dlsu.edu.ph/privacy/' fetched in 0.0540010929107666s
# 'http://bit.ly/DLSUCareDesk_' fetched in 0.05600380897521973s
# 'https://www.dlsu.edu.ph/about-dlsu/' fetched in 0.05800127983093262s'http://enroll.dlsu.edu.ph/dlsu/dts' fetched in 0.05900263786315918s
#
# 'https://www.dlsu-jrig.org/' fetched in 0.06102299690246582s
# 'https://www.dlsu.edu.ph/lasallianmission/' fetched in 0.06300854682922363s
# 'https://www.dlsu.edu.ph/colleges/' fetched in 0.06499886512756348s
# 'https://www.dlsu.edu.ph/dlsu-care-desk/' fetched in 0.06699967384338379s
# 'https://www.dlsu.edu.ph/wp-content/uploads/pdf/viewbook/graduate
# 'https://www.dlsu.edu.ph/contact-us-new-normal/' fetched in 0.13001585006713867s
# 'https://www.dlsu.edu.ph/joint-statement-on-the-news-report-of-the-national-task-force-to-end-local-communist-armed-conflict/' fetched in 0.13199877738952637s
# 'https://www.dlsu.edu.ph/inside/board-advisors/' fetched in 0.13500046730041504s
# 'https://www.dlsu.edu.ph/safe-space-act-ra11313/' fetched in 0.13700509071350098s
# 'https://www.dlsu.edu.ph/wp-content/uploads/pdf/viewbook/graduate/cla-graduate-viewbook.pdf' fetched in 0.1390058994293213s
# 'https://www.youtube.com/channel/UC7LXC9usdkDC0YEvWxa_kHQ' fetched in 0.1410057544708252s
# 'https://admissions.dlsu.edu.ph/application/ug/applicationform/adm_appl_type.aspx' fetched in 0.14300131797790527s
# 'https://www.dlsu.edu.ph/bituin/hr/' fetched in 0.14499974250793457s
# 'https://www.dlsu.edu.ph/conferences/' fetched in 0.14801621437072754s
# 'https://www.dlsu.edu.ph/connectivity-support/' fetched in 0.1500082015991211s
# 'https://www.dlsu.edu.ph/wp-content/uploads/pdf/announcements/t1-ay22-23-faqs-students.pdf' fetched in 0.15200209617614746s
# 'https://www.dlsu.edu.ph/emeriti/' fetched in 0.15400052070617676s
# 'https://www.dlsu.edu.ph/wp-content/uploads/pdf/viewbook/graduate/cos-graduate-viewbook.pdf' fetched in 0.15600037574768066s
# 'https://www.dlsu.edu.ph/integratedschool-test/senior-high-school/' fetched in 0.15902113914489746s
# 'https://animo.sys.dlsu.edu.ph' fetched in 0.16100096702575684s
# 'https://www.dlsu.edu.ph/animo-christmas-2022/' fetched in 0.16303038597106934s
# 'https://www.dlsu.edu.ph/research/' fetched in 0.1660020351409912s
# 'https://www.dlsu.edu.ph/offices/registrar/document_request/' fetched in 0.16801214218139648s
# 'https://www.dlsu.edu.ph/lasallians-r-e-a-c-h/' fetched in 0.17000198364257812s
# 'https://www.dlsu.edu.ph/admissions/graduate/graduate-viewbooks/' fetched in 0.17200469970703125s
# 'https://theconcierge.dlsu.edu.ph/' fetched in 0.17502713203430176s
# 'https://www.dlsu.edu.ph/one-in-mission-lasallians-mount-covid-19-relief-efforts-for-dlsu-community/' fetched in 0.17702078819274902s
# 'https://www.dlsu.edu.ph/about-dlsu/ourcorevalues/' fetched in 0.18004298210144043s
# 'https://www.dlsu.edu.ph/research/research-centers/censer/' fetched in 0.1820211410522461s
# 'https://www.dlsu.edu.ph/wp-content/uploads/pdf/viewbook/graduate/bag-ced-graduate-viewbook.pdf' fetched in 0.1840057373046875s
# 'https://www.dlsu.edu.ph/offices/office-of-the-chancellor/' fetched in 0.18602418899536133s
# 'https://www.dlsu.edu.ph/research/research-centers/ibeht/' fetched in 0.18801236152648926s
# Elapsed Time: 0.19201111793518066

# %% [markdown]
# # Get emails protected by cloudflare

# %% [markdown]
# # Pwede na ata di isama to kasi ayaw gumana

# %%
mydivs = soup.findAll("span",{"class": "__cf_email__"})

length = len(mydivs)

for x in range(length):
    a = cfDecodeEmail(mydivs[x]["data-cfemail"])
    print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-97c549394f6d> in <module>
#       4
#       5 for x in range(length):
# ----> 6     a = cfDecodeEmail(mydivs[x]["data-cfemail"])
#       7     print(a)
#
# NameError: name 'cfDecodeEmail' is not defined

# %%
print (mydivs[1]["data-cfemail"])
print(len(mydivs))
